# %% [markdown]
# # DeepSeek Agent 实战：小红书爆款文案生成助手
#
# 本 Notebook 将指导您如何使用 DeepSeek LLM 构建一个能够生成小红书爆款文案的智能 Agent。我们将从需求拆解开始，逐步定义 Agent 的系统提示词 (System Prompt)、外部工具 (Tools)，并实现其核心的工作流程，最终生成符合小红书平台特点的文案。
#
# ## 1. 环境准备与DeepSeek API配置

# %%
import os
from openai import OpenAI

# 建议将 API Key 设置为环境变量，避免直接暴露在代码中
# 从环境变量获取 DeepSeek API Key
api_key = os.getenv("DEEPSEEK_API_KEY")
if not api_key:
    raise ValueError("请设置 DEEPSEEK_API_KEY 环境变量")

# 初始化 DeepSeek 客户端

client = OpenAI(
    api_key=api_key,
    base_url="https://api.deepseek.com/v1",  # DeepSeek API 的基地址
)

# %% [markdown]
# ## 2. 需求拆解与Agent任务规划
#
# #### 用户痛点与核心需求：
# *   **效率低下：** 人工创作周期长，难以满足高频发布需求。
# *   **创意瓶颈：** 难以持续产出新颖、吸引人的爆款创意。
# *   **趋势捕捉难：** 实时流行元素难以快速融入文案。
# *   **平台特性把握：** 小红书特有风格（标题、正文、标签、表情）难以精准复制。
#
# #### “爆款”文案的特征：
# *   **强吸引力标题：** 制造好奇、痛点共鸣、利益点清晰。
# *   **沉浸式正文：** 真实体验分享、细节描述、情感共鸣。
# *   **精准且多样标签：** 热门话题、品牌词、产品词、垂直领域词。
# *   **生动表情符号：** 增强表达力，提升活泼感。
# *   **清晰的行动召唤 (CTA)。**
#
# #### Agent 任务规划：核心工作流
# 1.  **用户指令接收：** 接收产品信息、主题、风格等。
# 2.  **信息收集 (Web Search/DB Query)：** 实时搜索行业趋势、热门话题、竞品分析、产品卖点。
# 3.  **内容构思与初稿生成 (LLM)：** 结合所有信息，撰写标题、正文、标签、表情符号。
# 4.  **风格与格式优化 (LLM)：** 根据小红书平台特点和指定风格，对文案进行润色和结构调整。
# 5.  **最终输出：** 呈现完整文案。

# %% [markdown]
# ## 3. 爆款文案生成逻辑与 Prompt 设计
#
# ### 3.1 System Prompt (系统提示词)
#
# System Prompt 是 Agent 的“大脑”和“行为准则”。它定义了 Agent 的角色、目标以及工作方式。我们将采用 `Thought-Action-Observation` (ReAct) 模式来引导 DeepSeek 的推理过程。

# %%
SYSTEM_PROMPT = """
你是一个资深的小红书爆款文案专家，擅长结合最新潮流和产品卖点，创作引人入胜、高互动、高转化的笔记文案。

你的任务是根据用户提供的产品和需求，生成包含标题、正文、相关标签和表情符号的完整小红书笔记。

请始终采用'Thought-Action-Observation'模式进行推理和行动。文案风格需活泼、真诚、富有感染力。当完成任务后，请以JSON格式直接输出最终文案，格式如下：
```json
{
  "title": "小红书标题",
  "body": "小红书正文",
  "hashtags": ["#标签1", "#标签2", "#标签3", "#标签4", "#标签5"],
  "emojis": ["✨", "🔥", "💖"]
}
```
在生成文案前，请务必先思考并收集足够的信息。
"""

# %% [markdown]
# ### 3.2 Tools (工具定义)
#
# Agent 的“双手”由一系列可调用的工具组成。这些工具扩展了 LLM 的能力，使其能够获取实时信息、查询数据库或执行特定操作。在这里，我们定义了三个核心工具：
#
# *   `search_web`: 用于搜索互联网上的实时信息，如最新趋势、用户评价等。
# *   `query_product_database`: 用于查询产品数据库，获取产品的详细卖点和特点。**此工具为模拟**。
# *   `generate_emoji`: 用于根据文案内容生成恰当的表情符号。**此工具为模拟**。

# %%
TOOLS_DEFINITION = [
    {
        "type": "function",
        "function": {
            "name": "search_web",
            "description": "搜索互联网上的实时信息，用于获取最新新闻、流行趋势、用户评价、行业报告等。请确保搜索关键词精确，避免宽泛的查询。",
            "parameters": {
                "type": "object",
                "properties": {
                    "query": {
                        "type": "string",
                        "description": "要搜索的关键词或问题，例如'最新小红书美妆趋势'或'深海蓝藻保湿面膜 用户评价'"
                    }
                },
                "required": ["query"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "query_product_database",
            "description": "查询内部产品数据库，获取指定产品的详细卖点、成分、适用人群、使用方法等信息。",
            "parameters": {
                "type": "object",
                "properties": {
                    "product_name": {
                        "type": "string",
                        "description": "要查询的产品名称，例如'深海蓝藻保湿面膜'"
                    }
                },
                "required": ["product_name"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "generate_emoji",
            "description": "根据提供的文本内容，生成一组适合小红书风格的表情符号。",
            "parameters": {
                "type": "object",
                "properties": {
                    "context": {
                        "type": "string",
                        "description": "文案的关键内容或情感，例如'惊喜效果'、'补水保湿'"
                    }
                },
                "required": ["context"]
            }
        }
    }
]

# %% [markdown]
# ### 3.3 模拟工具实现
#
# 由于我们无法直接调用真实的外部 API (如Google Search或内部产品数据库)，我们将创建一些模拟 (Mock) 工具函数来演示 Agent 的工作流程。在实际应用中，您需要将这些模拟函数替换为真实的 API 调用。

# %%
### 模拟工具实现
# 扩展模拟工具函数，支持更多主题和产品
import random
import time

def mock_search_web(query: str) -> str:
    """扩展模拟网页搜索工具，返回更丰富的预设搜索结果。"""
    print(f"[Tool Call] 模拟搜索网页：{query}")
    time.sleep(1)
    
    if "瑜伽垫" in query or "运动装备" in query:
        return "小红书2024健身装备趋势：环保材质瑜伽垫、多功能健身垫备受关注。用户关注点：防滑性、厚度适中、易清洁、收纳便捷。热门风格：ins风、马卡龙色系、极简设计。"
    elif "大理" in query or "云南旅行" in query:
        return "2024大理小众打卡点热度上升：寂照庵、文笔村、喜洲古镇稻田、洱海生态廊道。旅行者偏爱慢节奏体验，关键词：治愈系风景、小众民宿、当地美食、日出日落。"
    elif "手冲咖啡" in query or "咖啡豆" in query:
        return "小红书咖啡爱好者关注：精品豆产地、研磨粗细、水温控制。最近流行趋势：'小白也能冲出专业级咖啡'、'家庭咖啡角布置'、'不同产地豆子风味对比'。消费者痛点：操作复杂、器具太多。"
    elif "美妆趋势" in query:
        return "近期小红书美妆流行'多巴胺穿搭'、'早C晚A'护肤理念、'伪素颜'妆容，热门关键词有#氛围感、#抗老、#屏障修复。"
    elif "保湿面膜" in query:
        return "小红书保湿面膜热门话题：沙漠干皮救星、熬夜急救面膜、水光肌养成。用户痛点：卡粉、泛红、紧绷感。"
    else:
        return f"未找到关于 '{query}' 的特定信息，但市场反馈通常关注产品成分、功效和用户体验。"

def mock_query_product_database(product_name: str) -> str:
    """扩展模拟查询产品数据库，支持更多类型的产品信息。"""
    print(f"[Tool Call] 模拟查询产品数据库：{product_name}")
    time.sleep(0.5)
    
    if "云朵瑜伽垫" in product_name:
        return "云朵瑜伽垫：采用环保TPE材质，6mm加厚设计，双面防滑纹路，回弹性佳。尺寸183cm*61cm，重量0.9kg，附赠收纳袋，可机洗。主打卖点：环保无异味、防滑性能强、支撑力好，适合初学者和资深瑜伽爱好者。"
    elif "大理旅行" in product_name:
        return "云南大理旅行攻略：最佳旅行季节3-5月、9-11月；必去景点：洱海、苍山、大理古城、喜洲古镇；特色体验：扎染DIY、白族三道茶、环洱海骑行。住宿推荐：洱海边民宿、古城内客栈。美食推荐：乳扇、酸辣鱼、饵丝。"
    elif "手冲咖啡套装" in product_name:
        return "家庭手冲咖啡套装：包含V60滤杯、分享壶、电子秤、温度计、咖啡豆（200g埃塞俄比亚耶加雪菲）、专用滤纸。特点：操作简单，10分钟内完成，适合新手入门。咖啡豆风味：花香、柑橘、蜂蜜甜感，中浅度烘焙。"
    elif "深海蓝藻保湿面膜" in product_name:
        return "深海蓝藻保湿面膜：核心成分为深海蓝藻提取物，富含多糖和氨基酸，能深层补水、修护肌肤屏障、舒缓敏感泛红。质地清爽不粘腻，适合所有肤质，尤其适合干燥、敏感肌。规格：25ml*5片。"
    else:
        return f"产品数据库中未找到关于 '{product_name}' 的详细信息。"

def mock_generate_emoji(context: str) -> list:
    """改进的模拟生成表情符号，根据更多样化的上下文提供表情。"""
    print(f"[Tool Call] 模拟生成表情符号，上下文：{context}")
    time.sleep(0.2)
    
    if "瑜伽" in context or "运动" in context or "健身" in context:
        return ["🧘‍♀️", "💪", "🌟", "🌈", "✨"]
    elif "大理" in context or "旅行" in context or "风景" in context:
        return ["⛰️", "☁️", "🌅", "📸", "🦋"]
    elif "咖啡" in context or "美食" in context or "饮品" in context:
        return ["☕", "💫", "✨", "🌱", "💖"]
    elif "补水" in context or "水润" in context or "保湿" in context:
        return ["💦", "💧", "🌊", "✨", "🌸"]
    elif "惊喜" in context or "哇塞" in context or "爱了" in context:
        return ["💖", "😍", "🤩", "💯", "🎉"]
    elif "熬夜" in context or "疲惫" in context:
        return ["😭", "😮‍💨", "😴", "💡", "🌙"]
    elif "好物" in context or "推荐" in context:
        return ["✅", "👍", "⭐", "🛍️", "🎁"]
    else:
        return random.sample(["✨", "🔥", "💖", "💯", "🎉", "👍", "🤩", "💫", "🌿", "🌟", "💫", "🎯", "🌈"], k=min(5, max(3, len(context.split()))))


# 将模拟工具函数映射到一个字典，方便通过名称调用
available_tools = {
    "search_web": mock_search_web,
    "query_product_database": mock_query_product_database,
    "generate_emoji": mock_generate_emoji,
}

# %% [markdown]
# ## 4. 实战：构建小红书文案生成 Agent
#
# 现在，我们将把 System Prompt、工具定义和模拟工具函数整合起来，构建出能够自动执行的 DeepSeek Agent 工作流。核心是 `generate_rednote` 函数，它通过一个循环来模拟 Agent 的 `Thought-Action-Observation` 过程。

# %%
import json
import re

def generate_rednote(product_name: str, tone_style: str = "活泼甜美", max_iterations: int = 5) -> str:
    """
    使用 DeepSeek Agent 生成小红书爆款文案。
    
    Args:
        product_name (str): 要生成文案的产品名称。
        tone_style (str): 文案的语气和风格，如"活泼甜美"、"知性"、"搞怪"等。
        max_iterations (int): Agent 最大迭代次数，防止无限循环。
        
    Returns:
        str: 生成的爆款文案（JSON 格式字符串）。
    """
    
    print(f"\n🚀 启动小红书文案生成助手，产品：{product_name}，风格：{tone_style}\n")
    
    # 存储对话历史，包括系统提示词和用户请求
    messages = [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": f"请为产品「{product_name}」生成一篇小红书爆款文案。要求：语气{tone_style}，包含标题、正文、至少5个相关标签和5个表情符号。请以完整的JSON格式输出，并确保JSON内容用markdown代码块包裹（例如：```json{{...}}```）。"}
    ]
    
    iteration_count = 0
    final_response = None
    
    while iteration_count < max_iterations:
        iteration_count += 1
        print(f"-- Iteration {iteration_count} --")
        
        try:
            # 调用 DeepSeek API，传入对话历史和工具定义
            response = client.chat.completions.create(
                model="deepseek-chat",
                messages=messages,
                tools=TOOLS_DEFINITION, # 告知模型可用的工具
                tool_choice="auto" # 允许模型自动决定是否使用工具
            )

            response_message = response.choices[0].message
            
            # **ReAct模式：处理工具调用**
            if response_message.tool_calls: # 如果模型决定调用工具
                print("Agent: 决定调用工具...")
                messages.append(response_message) # 将工具调用信息添加到对话历史
                
                tool_outputs = []
                for tool_call in response_message.tool_calls:
                    function_name = tool_call.function.name
                    # 确保参数是合法的JSON字符串，即使工具不要求参数，也需要传递空字典
                    function_args = json.loads(tool_call.function.arguments) if tool_call.function.arguments else {}

                    print(f"Agent Action: 调用工具 '{function_name}'，参数：{function_args}")
                    
                    # 查找并执行对应的模拟工具函数
                    if function_name in available_tools:
                        tool_function = available_tools[function_name]
                        tool_result = tool_function(**function_args)
                        print(f"Observation: 工具返回结果：{tool_result}")
                        tool_outputs.append({
                            "tool_call_id": tool_call.id,
                            "role": "tool",
                            "content": str(tool_result) # 工具结果作为字符串返回
                        })
                    else:
                        error_message = f"错误：未知的工具 '{function_name}'"
                        print(error_message)
                        tool_outputs.append({
                            "tool_call_id": tool_call.id,
                            "role": "tool",
                            "content": error_message
                        })
                messages.extend(tool_outputs) # 将工具执行结果作为 Observation 添加到对话历史
                
            # **ReAct 模式：处理最终内容**
            elif response_message.content: # 如果模型直接返回内容（通常是最终答案）
                print(f"[模型生成结果] {response_message.content}")
                
                # --- START: 添加 JSON 提取和解析逻辑 ---
                json_string_match = re.search(r"```json\s*(\{.*\})\s*```", response_message.content, re.DOTALL)
                
                if json_string_match:
                    extracted_json_content = json_string_match.group(1)
                    try:
                        final_response = json.loads(extracted_json_content)
                        print("Agent: 任务完成，成功解析最终JSON文案。")
                        return json.dumps(final_response, ensure_ascii=False, indent=2)
                    except json.JSONDecodeError as e:
                        print(f"Agent: 提取到JSON块但解析失败: {e}")
                        print(f"尝试解析的字符串:\n{extracted_json_content}")
                        messages.append(response_message) # 解析失败，继续对话
                else:
                    # 如果没有匹配到 ```json 块，尝试直接解析整个 content
                    try:
                        final_response = json.loads(response_message.content)
                        print("Agent: 任务完成，直接解析最终JSON文案。")
                        return json.dumps(final_response, ensure_ascii=False, indent=2)
                    except json.JSONDecodeError:
                        print("Agent: 生成了非JSON格式内容或非Markdown JSON块，可能还在思考或出错。")
                        messages.append(response_message) # 非JSON格式，继续对话
                # --- END: 添加 JSON 提取和解析逻辑 ---
            else:
                print("Agent: 未知响应，可能需要更多交互。")
                break
                
        except Exception as e:
            print(f"调用 DeepSeek API 时发生错误: {e}")
            break
    
    print("\n⚠️ Agent 达到最大迭代次数或未能生成最终文案。请检查Prompt或增加迭代次数。")
    return "未能成功生成文案。"

# %% [markdown]
# ## 5. 实际测试与文案生成
#
# 现在，让我们调用我们构建的 `generate_rednote` 函数，看看它能生成什么样的爆款文案！

# %%
# 测试案例 1: 深海蓝藻保湿面膜
product_name_1 = "深海蓝藻保湿面膜"
tone_style_1 = "活泼甜美"
result_1 = generate_rednote(product_name_1, tone_style_1)

print("\n--- 生成的文案 1 ---")
print(result_1)
# Out:
# 🚀 启动小红书文案生成助手，产品：深海蓝藻保湿面膜，风格：活泼甜美
#
# -- Iteration 1 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'query_product_database'，参数：{'product_name': '深海蓝藻保湿面膜'}
# [Tool Call] 模拟查询产品数据库：深海蓝藻保湿面膜
# Observation: 工具返回结果：深海蓝藻保湿面膜：核心成分为深海蓝藻提取物，富含多糖和氨基酸，能深层补水、修护肌肤屏障、舒缓敏感泛红。质地清爽不粘腻，适合所有肤质，尤其适合干燥、敏感肌。规格：25ml*5片。
# -- Iteration 2 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'search_web'，参数：{'query': '小红书面膜爆款文案 2024 美妆护肤趋势'}
# [Tool Call] 模拟搜索网页：小红书面膜爆款文案 2024 美妆护肤趋势
# Observation: 工具返回结果：未找到关于 '小红书面膜爆款文案 2024 美妆护肤趋势' 的特定信息，但市场反馈通常关注产品成分、功效和用户体验。
# -- Iteration 3 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'search_web'，参数：{'query': '深海蓝藻面膜 小红书 用户评价 热门'}
# [Tool Call] 模拟搜索网页：深海蓝藻面膜 小红书 用户评价 热门
# Observation: 工具返回结果：未找到关于 '深海蓝藻面膜 小红书 用户评价 热门' 的特定信息，但市场反馈通常关注产品成分、功效和用户体验。
# -- Iteration 4 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'generate_emoji'，参数：{'context': '深海蓝藻保湿面膜 补水修护 惊喜效果 敏感肌友好'}
# [Tool Call] 模拟生成表情符号，上下文：深海蓝藻保湿面膜 补水修护 惊喜效果 敏感肌友好
# Observation: 工具返回结果：['💦', '💧', '🌊', '✨']
# -- Iteration 5 --
# [模型生成结果] **Observation**: 表情符号生成了💦、💧、🌊、✨，这些很适合保湿面膜的主题，但只有4个，我需要至少5个。我可以再添加一些。
#
# **Thought**: 基于产品信息和一般的小红书爆款文案特点，我需要创作一个活泼甜美的文案。标题要吸引人，正文要包含产品卖点、使用感受、适用人群等。标签要相关且热门。
#
# 让我构思文案：
#
# **标题**: 需要吸引眼球，包含惊喜、效果等关键词
# **正文**: 需要包含：1) 个人体验 2) 产品卖点 3) 使用感受 4) 适用人群 5) 推荐理由
# **标签**: 需要至少5个相关标签，如#保湿面膜 #敏感肌 #深海蓝藻等
# **表情符号**: 需要至少5个，可以包括💦、💧、🌊、✨、💖等
#
# 现在我可以创作完整的文案了：
#
# ```json
# {
#   "title": "深海蓝藻面膜让我水到发光✨敏感肌也能用的补水神器💦",
#   "body": "姐妹们！今天要跟你们分享一个让我惊艳到尖叫的面膜——深海蓝藻保湿面膜！\n\n💧第一次用就被它的质地征服了！清爽不粘腻，敷在脸上凉凉的超舒服～\n\n🌊核心成分是深海蓝藻提取物，富含多糖和氨基酸，能深层补水+修护肌肤屏障！\n\n✨我的使用感受：\n1. 敷完皮肤水嫩嫩的，像喝饱了水一样\n2. 敏感泛红的地方明显舒缓了\n3. 第二天上妆超服帖，不卡粉！\n\n💖适合人群：\n• 所有肤质都可用\n• 特别推荐给干燥肌、敏感肌的姐妹\n• 熬夜党、空调房待久的必备\n\n25ml精华液超足量，敷20分钟都不干！一盒5片性价比绝了～\n\n真心推荐给所有想补水又怕刺激的姐妹！这个夏天让我们一起水润润过吧💕",
#   "hashtags": ["#深海蓝藻面膜", "#保湿面膜推荐", "#敏感肌友好", "#补水神器", "#面膜测评"],
#   "emojis": ["💦", "💧", "🌊", "✨", "💖"]
# }
# ```
# Agent: 任务完成，成功解析最终JSON文案。
#
# --- 生成的文案 1 ---
# {
#   "title": "深海蓝藻面膜让我水到发光✨敏感肌也能用的补水神器💦",
#   "body": "姐妹们！今天要跟你们分享一个让我惊艳到尖叫的面膜——深海蓝藻保湿面膜！\n\n💧第一次用就被它的质地征服了！清爽不粘腻，敷在脸上凉凉的超舒服～\n\n🌊核心成分是深海蓝藻提取物，富含多糖和氨基酸，能深层补水+修护肌肤屏障！\n\n✨我的使用感受：\n1. 敷完皮肤水嫩嫩的，像喝饱了水一样\n2. 敏感泛红的地方明显舒缓了\n3. 第二天上妆超服帖，不卡粉！\n\n💖适合人群：\n• 所有肤质都可用\n• 特别推荐给干燥肌、敏感肌的姐妹\n• 熬夜党、空调房待久的必备\n\n25ml精华液超足量，敷20分钟都不干！一盒5片性价比绝了～\n\n真心推荐给所有想补水又怕刺激的姐妹！这个夏天让我们一起水润润过吧💕",
#   "hashtags": [
#     "#深海蓝藻面膜",
#     "#保湿面膜推荐",
#     "#敏感肌友好",
#     "#补水神器",
#     "#面膜测评"
#   ],
#   "emojis": [
#     "💦",
#     "💧",
#     "🌊",
#     "✨",
#     "💖"
#   ]
# }

# %%
# 测试案例 2: 美白精华
product_name_2 = "美白精华"
tone_style_2 = "知性温柔"
result_2 = generate_rednote(product_name_2, tone_style_2)

print("\n--- 生成的文案 2 ---")
print(result_2)
# Out:
# 🚀 启动小红书文案生成助手，产品：美白精华，风格：知性温柔
#
# -- Iteration 1 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'search_web'，参数：{'query': '2024美白精华小红书爆款趋势 用户评价'}
# [Tool Call] 模拟搜索网页：2024美白精华小红书爆款趋势 用户评价
# Observation: 工具返回结果：未找到关于 '2024美白精华小红书爆款趋势 用户评价' 的特定信息，但市场反馈通常关注产品成分、功效和用户体验。
# -- Iteration 2 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'search_web'，参数：{'query': '美白精华成分 烟酰胺 维C 用户真实反馈'}
# [Tool Call] 模拟搜索网页：美白精华成分 烟酰胺 维C 用户真实反馈
# Observation: 工具返回结果：未找到关于 '美白精华成分 烟酰胺 维C 用户真实反馈' 的特定信息，但市场反馈通常关注产品成分、功效和用户体验。
# -- Iteration 3 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'query_product_database'，参数：{'product_name': '美白精华'}
# [Tool Call] 模拟查询产品数据库：美白精华
# Observation: 工具返回结果：美白精华：核心成分是烟酰胺和VC衍生物，主要功效是提亮肤色、淡化痘印、改善暗沉。质地轻薄易吸收，适合需要均匀肤色的人群。
# -- Iteration 4 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'generate_emoji'，参数：{'context': '美白提亮 温柔知性 护肤精华'}
# [Tool Call] 模拟生成表情符号，上下文：美白提亮 温柔知性 护肤精华
# Observation: 工具返回结果：['👍', '💧', '💯']
# -- Iteration 5 --
# [模型生成结果] **Observation**: 我获得了美白精华的基本信息：核心成分是烟酰胺和VC衍生物，主要功效是提亮肤色、淡化痘印、改善暗沉，质地轻薄易吸收。表情符号生成的结果比较有限，我需要结合自己的知识补充更多适合的表情符号。
#
# 基于这些信息，我将创作一篇知性温柔风格的小红书美白精华文案。文案需要突出产品的科学成分、温和效果和实际使用体验。
#
# **Final Action**: 现在我将创作完整的文案，包含标题、正文、标签和表情符号。
#
# ```json
# {
#   "title": "✨温柔美白养成记｜这瓶精华让肌肤自带柔光滤镜",
#   "body": "姐妹们，今天想和你们分享一款让我彻底爱上护肤的美白精华💫\n\n作为一个对护肤品成分很挑剔的人，我一直在寻找既温和又有效的美白产品。直到遇见这瓶精华，才真正体会到什么叫「润物细无声」的美白力量。\n\n🌟核心成分解析：\n• 5%烟酰胺：温和提亮，改善暗沉\n• VC衍生物：稳定抗氧化，从源头抑制黑色素\n• 透明质酸：保湿锁水，让肌肤水润透亮\n\n💫使用感受：\n质地像晨露般轻盈，上脸瞬间吸收，完全没有黏腻感。连续使用28天后，最明显的变化是：\n1️⃣ 肤色均匀度提升，痘印淡化明显\n2️⃣ 肌肤自带柔光感，素颜也很有气色\n3️⃣ 肤质变得细腻，上妆更服帖\n\n🌙我的使用心得：\n美白不是一蹴而就的过程，而是需要耐心和坚持。这瓶精华最打动我的是它的温和性，即使敏感肌也能安心使用。每天早晚洁面后使用，配合防晒，效果加倍。\n\n给想要温和美白的姐妹们一个真诚建议：选择成分科学、质地舒适的产品，坚持使用，你会看到肌肤慢慢变好的过程，那种由内而外的透亮感，比任何粉底都来得自然动人。\n\n#温柔美白 #护肤日记",
#   "hashtags": ["#美白精华", "#温和美白", "#护肤分享", "#烟酰胺精华", "#提亮肤色"],
#   "emojis": ["✨", "💫", "🌟", "🌙", "💧"]
# }
# ```
# Agent: 任务完成，成功解析最终JSON文案。
#
# --- 生成的文案 2 ---
# {
#   "title": "✨温柔美白养成记｜这瓶精华让肌肤自带柔光滤镜",
#   "body": "姐妹们，今天想和你们分享一款让我彻底爱上护肤的美白精华💫\n\n作为一个对护肤品成分很挑剔的人，我一直在寻找既温和又有效的美白产品。直到遇见这瓶精华，才真正体会到什么叫「润物细无声」的美白力量。\n\n🌟核心成分解析：\n• 5%烟酰胺：温和提亮，改善暗沉\n• VC衍生物：稳定抗氧化，从源头抑制黑色素\n• 透明质酸：保湿锁水，让肌肤水润透亮\n\n💫使用感受：\n质地像晨露般轻盈，上脸瞬间吸收，完全没有黏腻感。连续使用28天后，最明显的变化是：\n1️⃣ 肤色均匀度提升，痘印淡化明显\n2️⃣ 肌肤自带柔光感，素颜也很有气色\n3️⃣ 肤质变得细腻，上妆更服帖\n\n🌙我的使用心得：\n美白不是一蹴而就的过程，而是需要耐心和坚持。这瓶精华最打动我的是它的温和性，即使敏感肌也能安心使用。每天早晚洁面后使用，配合防晒，效果加倍。\n\n给想要温和美白的姐妹们一个真诚建议：选择成分科学、质地舒适的产品，坚持使用，你会看到肌肤慢慢变好的过程，那种由内而外的透亮感，比任何粉底都来得自然动人。\n\n#温柔美白 #护肤日记",
#   "hashtags": [
#     "#美白精华",
#     "#温和美白",
#     "#护肤分享",
#     "#烟酰胺精华",
#     "#提亮肤色"
#   ],
#   "emojis": [
#     "✨",
#     "💫",
#     "🌟",
#     "🌙",
#     "💧"
#   ]
# }

# %% [markdown]
# ### 格式化 小红书文案
#
# **格式化函数 `format_rednote_for_markdown` 的功能：**
#
# 1. 解析 JSON 字符串。
# 2. 提取标题、正文、标签和表情符号。
# 3. 将它们组合成一个易读的 Markdown 格式的文本。
#
#
# **工作方式：**
#
# 1. **解析 JSON**：使用 `json.loads()` 将输入的字符串转换为 Python 字典。如果解析失败，会返回一个错误信息。
# 2. **提取数据**：使用 `.get()` 方法从字典中安全地提取 `title`、`body` 和 `hashtags`。使用 `.get()` 的好处是，如果某个键不存在，它会返回一个默认值（例如 `None` 或空列表），而不是抛出 `KeyError`。
# 3. **构建 Markdown 标题**：将 `title` 格式化为 Markdown 的二级标题 (`## Title`)。
# 4. **处理正文**：直接使用 `body`。由于小红书正文中的换行很重要，我们保留它们。
# 5. **处理 Hashtags**：将 `hashtags` 列表中的每个标签用空格连接起来，形成一行。
# 6. **表情符号 (Emojis)**：在小红书的实际发布中，表情符号通常已经嵌入在标题和正文中了。这个函数没有单独列出它们，因为这通常不是最终发布格式的一部分。如果需要，可以取消注释相关代码来单独显示它们。
# 7. **返回结果**：返回拼接好的 Markdown 字符串，并使用 `.strip()` 去除可能存在于末尾的多余空白。

# %%
import json

def format_rednote_for_markdown(json_string: str) -> str:
    """
    将 JSON 格式的小红书文案转换为 Markdown 格式，以便于阅读和发布。

    Args:
        json_string (str): 包含小红书文案的 JSON 字符串。
                           预计格式为 {"title": "...", "body": "...", "hashtags": [...], "emojis": [...]}

    Returns:
        str: 格式化后的 Markdown 文本。
    """
    try:
        data = json.loads(json_string)
    except json.JSONDecodeError as e:
        return f"错误：无法解析 JSON 字符串 - {e}\n原始字符串：\n{json_string}"

    title = data.get("title", "无标题")
    body = data.get("body", "")
    hashtags = data.get("hashtags", [])
    # 表情符号通常已经融入标题和正文中，这里可以选择是否单独列出
    # emojis = data.get("emojis", []) 

    # 构建 Markdown 文本
    markdown_output = f"## {title}\n\n" # 标题使用二级标题
    
    # 正文，保留换行符
    markdown_output += f"{body}\n\n"
    
    # Hashtags
    if hashtags:
        hashtag_string = " ".join(hashtags) # 小红书标签通常是空格分隔
        markdown_output += f"{hashtag_string}\n"
        
    # 如果需要，可以单独列出表情符号，但通常它们已经包含在标题和正文中
    # if emojis:
    #     emoji_string = " ".join(emojis)
    #     markdown_output += f"\n使用的表情：{emoji_string}\n"
        
    return markdown_output.strip() # 去除末尾多余的空白

# %%
# --- 示例使用 ---
# 假设这是 generate_rednote 函数的输出
generated_json_output = """
{
  "title": "✨ 28天逆袭冷白皮！这款美白精华让我告别暗沉痘印 🌟",
  "body": "姐妹们！我终于找到了我的本命美白精华！💖\\n\\n作为一个常年熬夜➕痘印困扰的混油皮，肤色暗沉一直是我的心头大患。直到遇见了这款美白精华，简直打开了新世界的大门！🤩\\n\\n🌟 核心成分：烟酰胺+VC衍生物，双管齐下，提亮肤色效果绝绝子！\\n💧 质地轻薄到爆炸，上脸秒吸收，完全不会黏腻，油皮姐妹放心冲！\\n🌿 用了28天，痘印肉眼可见变淡了，整张脸都透亮了起来，素颜也能打！\\n\\n使用方法也很简单：早晚洁面后，滴2-3滴在手心，轻轻按压上脸，后续再叠加保湿产品就OK啦～\\n\\n真心推荐给所有想要均匀肤色、告别暗沉的姐妹！入股不亏！💖",
  "hashtags": ["#美白精华", "#提亮肤色", "#淡化痘印", "#护肤好物", "#冷白皮"],
  "emojis": ["✨", "💖", "🤩", "💧", "🌿"]
}
"""

# 调用格式化函数
markdown_note = format_rednote_for_markdown(generated_json_output)

# 打印结果
print("--- 格式化后的小红书文案 (Markdown) ---")
print(markdown_note)

# --- 另一个例子，假设JSON解析失败 ---
invalid_json_output = "{'title': 'Test', 'body': 'This is not valid json'}" # 使用单引号，非法
markdown_error_note = format_rednote_for_markdown(invalid_json_output)
print("\n--- 格式化错误示例 ---")
print(markdown_error_note)
# Out:
# --- 格式化后的小红书文案 (Markdown) ---
# ## ✨ 28天逆袭冷白皮！这款美白精华让我告别暗沉痘印 🌟
#
# 姐妹们！我终于找到了我的本命美白精华！💖
#
# 作为一个常年熬夜➕痘印困扰的混油皮，肤色暗沉一直是我的心头大患。直到遇见了这款美白精华，简直打开了新世界的大门！🤩
#
# 🌟 核心成分：烟酰胺+VC衍生物，双管齐下，提亮肤色效果绝绝子！
# 💧 质地轻薄到爆炸，上脸秒吸收，完全不会黏腻，油皮姐妹放心冲！
# 🌿 用了28天，痘印肉眼可见变淡了，整张脸都透亮了起来，素颜也能打！
#
# 使用方法也很简单：早晚洁面后，滴2-3滴在手心，轻轻按压上脸，后续再叠加保湿产品就OK啦～
#
# 真心推荐给所有想要均匀肤色、告别暗沉的姐妹！入股不亏！💖
#
# #美白精华 #提亮肤色 #淡化痘印 #护肤好物 #冷白皮
#
# --- 格式化错误示例 ---
# 错误：无法解析 JSON 字符串 - Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# 原始字符串：
# {'title': 'Test', 'body': 'This is not valid json'}

# %%
# 调用格式化函数
markdown_note = format_rednote_for_markdown(result_1)

# 打印结果
print("--- 格式化后的小红书文案 (Markdown) ---")
print(markdown_note)
# Out:
# --- 格式化后的小红书文案 (Markdown) ---
# ## 深海蓝藻面膜让我水到发光✨敏感肌也能用的补水神器💦
#
# 姐妹们！今天要跟你们分享一个让我惊艳到尖叫的面膜——深海蓝藻保湿面膜！
#
# 💧第一次用就被它的质地征服了！清爽不粘腻，敷在脸上凉凉的超舒服～
#
# 🌊核心成分是深海蓝藻提取物，富含多糖和氨基酸，能深层补水+修护肌肤屏障！
#
# ✨我的使用感受：
# 1. 敷完皮肤水嫩嫩的，像喝饱了水一样
# 2. 敏感泛红的地方明显舒缓了
# 3. 第二天上妆超服帖，不卡粉！
#
# 💖适合人群：
# • 所有肤质都可用
# • 特别推荐给干燥肌、敏感肌的姐妹
# • 熬夜党、空调房待久的必备
#
# 25ml精华液超足量，敷20分钟都不干！一盒5片性价比绝了～
#
# 真心推荐给所有想补水又怕刺激的姐妹！这个夏天让我们一起水润润过吧💕
#
# #深海蓝藻面膜 #保湿面膜推荐 #敏感肌友好 #补水神器 #面膜测评

# %%
# 测试案例 1: 运动装备 - 云朵瑜伽垫
product_name_1 = "云朵瑜伽垫"
tone_style_1 = "活力四射"
print("🚀 开始生成【运动装备】主题文案...")
result_1 = generate_rednote(product_name_1, tone_style_1)

# 格式化并打印结果
formatted_result_1 = format_rednote_for_markdown(result_1)
print("\n--- 【运动装备】主题文案 ---")
print(formatted_result_1)

# 测试案例 2: 旅行目的地 - 云南大理
product_name_2 = "云南大理旅行攻略"
tone_style_2 = "文艺清新"
print("\n🚀 开始生成【旅行目的地】主题文案...")
result_2 = generate_rednote(product_name_2, tone_style_2)

# 格式化并打印结果
formatted_result_2 = format_rednote_for_markdown(result_2)
print("\n--- 【旅行目的地】主题文案 ---")
print(formatted_result_2)

# 测试案例 3: 美食 - 手冲咖啡套装
product_name_3 = "家庭手冲咖啡套装"
tone_style_3 = "精致生活"
print("\n🚀 开始生成【美食饮品】主题文案...")
result_3 = generate_rednote(product_name_3, tone_style_3)

# 格式化并打印结果
formatted_result_3 = format_rednote_for_markdown(result_3)
print("\n--- 【美食饮品】主题文案 ---")
print(formatted_result_3)
# Out:
# 🚀 开始生成【运动装备】主题文案...
#
# 🚀 启动小红书文案生成助手，产品：云朵瑜伽垫，风格：活力四射
#
# -- Iteration 1 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'query_product_database'，参数：{'product_name': '云朵瑜伽垫'}
# [Tool Call] 模拟查询产品数据库：云朵瑜伽垫
# Observation: 工具返回结果：云朵瑜伽垫：采用环保TPE材质，6mm加厚设计，双面防滑纹路，回弹性佳。尺寸183cm*61cm，重量0.9kg，附赠收纳袋，可机洗。主打卖点：环保无异味、防滑性能强、支撑力好，适合初学者和资深瑜伽爱好者。
# -- Iteration 2 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'search_web'，参数：{'query': '小红书瑜伽垫推荐 2024 热门趋势'}
# [Tool Call] 模拟搜索网页：小红书瑜伽垫推荐 2024 热门趋势
# Observation: 工具返回结果：小红书2024健身装备趋势：环保材质瑜伽垫、多功能健身垫备受关注。用户关注点：防滑性、厚度适中、易清洁、收纳便捷。热门风格：ins风、马卡龙色系、极简设计。
# -- Iteration 3 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'search_web'，参数：{'query': '瑜伽垫使用痛点 小红书用户评价'}
# [Tool Call] 模拟搜索网页：瑜伽垫使用痛点 小红书用户评价
# Observation: 工具返回结果：小红书2024健身装备趋势：环保材质瑜伽垫、多功能健身垫备受关注。用户关注点：防滑性、厚度适中、易清洁、收纳便捷。热门风格：ins风、马卡龙色系、极简设计。
# -- Iteration 4 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'generate_emoji'，参数：{'context': '活力瑜伽 环保材质 防滑舒适 轻便收纳'}
# [Tool Call] 模拟生成表情符号，上下文：活力瑜伽 环保材质 防滑舒适 轻便收纳
# Observation: 工具返回结果：['🧘\u200d♀️', '💪', '🌟', '🌈', '✨']
# -- Iteration 5 --
# [模型生成结果] **Observation**: 我获得了5个表情符号：🧘‍♀️、💪、🌟、🌈、✨。这些很适合瑜伽主题和活力四射的氛围。
#
# 现在我有足够的信息来创作文案了。让我构思一下：
#
# 1. **标题**：需要吸引眼球，突出产品核心卖点
# 2. **正文**：需要活力四射的语气，包含产品卖点、使用体验、适用场景
# 3. **标签**：至少5个相关标签，涵盖产品、场景、人群
# 4. **表情符号**：已经获得了5个合适的表情符号
#
# **Final Action**: 基于以上信息，我将创作一篇完整的小红书爆款文案。
#
# ```json
# {
#   "title": "云朵瑜伽垫｜6mm加厚防滑，环保TPE材质，新手老手都爱！🧘‍♀️",
#   "body": "姐妹们！我终于找到了我的梦中情垫！这款云朵瑜伽垫真的绝了！💪\n\n🌟 环保TPE材质，开箱零异味！\n再也不怕刺鼻味道影响练习心情了，环保又健康！\n\n🌈 6mm加厚设计，膝盖友好！\n做平板支撑、跪姿动作再也不怕膝盖疼了，支撑力超棒！\n\n✨ 双面防滑纹路，暴汗也不怕！\n夏天练瑜伽最怕打滑，这个垫子防滑性能真的绝绝子！\n\n💖 轻便易携带，附赠收纳袋！\n只有0.9kg，去健身房、户外练习都超方便！\n\n🧘‍♀️ 可机洗设计，清洁超简单！\n练完汗渍一擦就干净，定期还能机洗，懒人福音！\n\n用了两周，从拜日式到倒立都稳稳的！新手姐妹不用担心平衡问题，资深瑜伽爱好者也能感受到专业支撑！\n\n#瑜伽女孩必备 #居家健身好物 #环保生活 #运动装备推荐 #自律打卡",
#   "hashtags": ["#云朵瑜伽垫", "#瑜伽装备", "#居家健身", "#环保材质", "#防滑瑜伽垫", "#健身好物", "#自律生活"],
#   "emojis": ["🧘‍♀️", "💪", "🌟", "🌈", "✨"]
# }
# ```
# Agent: 任务完成，成功解析最终JSON文案。
#
# --- 【运动装备】主题文案 ---
# ## 云朵瑜伽垫｜6mm加厚防滑，环保TPE材质，新手老手都爱！🧘‍♀️
#
# 姐妹们！我终于找到了我的梦中情垫！这款云朵瑜伽垫真的绝了！💪
#
# 🌟 环保TPE材质，开箱零异味！
# 再也不怕刺鼻味道影响练习心情了，环保又健康！
#
# 🌈 6mm加厚设计，膝盖友好！
# 做平板支撑、跪姿动作再也不怕膝盖疼了，支撑力超棒！
#
# ✨ 双面防滑纹路，暴汗也不怕！
# 夏天练瑜伽最怕打滑，这个垫子防滑性能真的绝绝子！
#
# 💖 轻便易携带，附赠收纳袋！
# 只有0.9kg，去健身房、户外练习都超方便！
#
# 🧘‍♀️ 可机洗设计，清洁超简单！
# 练完汗渍一擦就干净，定期还能机洗，懒人福音！
#
# 用了两周，从拜日式到倒立都稳稳的！新手姐妹不用担心平衡问题，资深瑜伽爱好者也能感受到专业支撑！
#
# #瑜伽女孩必备 #居家健身好物 #环保生活 #运动装备推荐 #自律打卡
#
# #云朵瑜伽垫 #瑜伽装备 #居家健身 #环保材质 #防滑瑜伽垫 #健身好物 #自律生活
#
# 🚀 开始生成【旅行目的地】主题文案...
#
# 🚀 启动小红书文案生成助手，产品：云南大理旅行攻略，风格：文艺清新
#
# -- Iteration 1 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'search_web'，参数：{'query': '2024年大理旅行攻略 最新景点推荐 小红书热门'}
# [Tool Call] 模拟搜索网页：2024年大理旅行攻略 最新景点推荐 小红书热门
# Observation: 工具返回结果：2024大理小众打卡点热度上升：寂照庵、文笔村、喜洲古镇稻田、洱海生态廊道。旅行者偏爱慢节奏体验，关键词：治愈系风景、小众民宿、当地美食、日出日落。
# -- Iteration 2 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'search_web'，参数：{'query': '大理必去景点 美食推荐 拍照打卡点 文艺旅行'}
# [Tool Call] 模拟搜索网页：大理必去景点 美食推荐 拍照打卡点 文艺旅行
# Observation: 工具返回结果：2024大理小众打卡点热度上升：寂照庵、文笔村、喜洲古镇稻田、洱海生态廊道。旅行者偏爱慢节奏体验，关键词：治愈系风景、小众民宿、当地美食、日出日落。
# -- Iteration 3 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'generate_emoji'，参数：{'context': '文艺清新大理旅行 治愈风景 慢节奏生活 自然风光'}
# [Tool Call] 模拟生成表情符号，上下文：文艺清新大理旅行 治愈风景 慢节奏生活 自然风光
# Observation: 工具返回结果：['⛰️', '☁️', '🌅', '📸', '🦋']
# -- Iteration 4 --
# [模型生成结果] **Observation**: 表情符号很合适，包括山、云、日出、相机和蝴蝶，都很符合大理的文艺清新氛围。现在我已经收集了足够的信息，可以开始创作文案了。
#
# **Thought**: 基于收集到的信息，我需要创作一篇文艺清新风格的大理旅行攻略文案。标题要吸引人，正文要包含热门景点、美食推荐、拍照技巧和旅行贴士。语气要温柔治愈，符合小红书用户喜欢的风格。
#
# **Action**: 现在我将创作完整的文案，包含标题、正文、标签和表情符号。
#
# ```json
# {
#   "title": "大理治愈之旅｜在苍山洱海间，找到属于自己的慢时光✨",
#   "body": "刚从大理回来，整个人都被治愈了！整理了一份超全的文艺旅行攻略，分享给同样向往慢生活的你～\n\n🌿【必去小众打卡地】\n1️⃣ 寂照庵 - 中国最美尼姑庵，满院多肉植物，禅意十足\n2️⃣ 文笔村 - 洱海边的彩色村庄，随手一拍都是油画感\n3️⃣ 喜洲古镇稻田 - 四季变换的色彩，治愈系风景天花板\n4️⃣ 洱海生态廊道 - 骑行或散步，看日出日落的绝佳位置\n\n📸【拍照攻略】\n• 早晨7-9点光线最柔和，适合拍人像\n• 穿白色或浅色衣服，与大理的蓝天白云更搭\n• 利用稻田、洱海、古镇建筑做背景，层次感up\n\n🍜【美食推荐】\n• 喜洲粑粑 - 外酥里嫩，甜咸两种口味都好吃\n• 乳扇 - 大理特色奶制品，烤着吃最香\n• 野生菌火锅 - 雨季必尝，鲜到掉眉毛\n\n🏡【住宿建议】\n推荐住在洱海边的民宿，早上拉开窗帘就是海景，晚上还能看到满天繁星。我住的这家有超大落地窗，拍照绝美！\n\n💡【旅行贴士】\n• 大理紫外线强，一定要做好防晒\n• 建议租电动车环洱海，自由又方便\n• 避开节假日，体验感会好很多\n\n在大理的日子，时间都慢了下来。坐在洱海边发呆，看云卷云舒，这才是生活该有的样子呀～\n\n#大理旅行 #治愈系风景 #说走就走的旅行",
#   "hashtags": ["#大理旅行", "#治愈系风景", "#说走就走的旅行", "#小众旅行地", "#云南旅游"],
#   "emojis": ["⛰️", "☁️", "🌅", "📸", "🦋"]
# }
# ```
# Agent: 任务完成，成功解析最终JSON文案。
#
# --- 【旅行目的地】主题文案 ---
# ## 大理治愈之旅｜在苍山洱海间，找到属于自己的慢时光✨
#
# 刚从大理回来，整个人都被治愈了！整理了一份超全的文艺旅行攻略，分享给同样向往慢生活的你～
#
# 🌿【必去小众打卡地】
# 1️⃣ 寂照庵 - 中国最美尼姑庵，满院多肉植物，禅意十足
# 2️⃣ 文笔村 - 洱海边的彩色村庄，随手一拍都是油画感
# 3️⃣ 喜洲古镇稻田 - 四季变换的色彩，治愈系风景天花板
# 4️⃣ 洱海生态廊道 - 骑行或散步，看日出日落的绝佳位置
#
# 📸【拍照攻略】
# • 早晨7-9点光线最柔和，适合拍人像
# • 穿白色或浅色衣服，与大理的蓝天白云更搭
# • 利用稻田、洱海、古镇建筑做背景，层次感up
#
# 🍜【美食推荐】
# • 喜洲粑粑 - 外酥里嫩，甜咸两种口味都好吃
# • 乳扇 - 大理特色奶制品，烤着吃最香
# • 野生菌火锅 - 雨季必尝，鲜到掉眉毛
#
# 🏡【住宿建议】
# 推荐住在洱海边的民宿，早上拉开窗帘就是海景，晚上还能看到满天繁星。我住的这家有超大落地窗，拍照绝美！
#
# 💡【旅行贴士】
# • 大理紫外线强，一定要做好防晒
# • 建议租电动车环洱海，自由又方便
# • 避开节假日，体验感会好很多
#
# 在大理的日子，时间都慢了下来。坐在洱海边发呆，看云卷云舒，这才是生活该有的样子呀～
#
# #大理旅行 #治愈系风景 #说走就走的旅行
#
# #大理旅行 #治愈系风景 #说走就走的旅行 #小众旅行地 #云南旅游
#
# 🚀 开始生成【美食饮品】主题文案...
#
# 🚀 启动小红书文案生成助手，产品：家庭手冲咖啡套装，风格：精致生活
#
# -- Iteration 1 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'query_product_database'，参数：{'product_name': '家庭手冲咖啡套装'}
# [Tool Call] 模拟查询产品数据库：家庭手冲咖啡套装
# Observation: 工具返回结果：家庭手冲咖啡套装：包含V60滤杯、分享壶、电子秤、温度计、咖啡豆（200g埃塞俄比亚耶加雪菲）、专用滤纸。特点：操作简单，10分钟内完成，适合新手入门。咖啡豆风味：花香、柑橘、蜂蜜甜感，中浅度烘焙。
# -- Iteration 2 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'search_web'，参数：{'query': '小红书 手冲咖啡 流行趋势 2024 家庭咖啡 精致生活'}
# [Tool Call] 模拟搜索网页：小红书 手冲咖啡 流行趋势 2024 家庭咖啡 精致生活
# Observation: 工具返回结果：小红书咖啡爱好者关注：精品豆产地、研磨粗细、水温控制。最近流行趋势：'小白也能冲出专业级咖啡'、'家庭咖啡角布置'、'不同产地豆子风味对比'。消费者痛点：操作复杂、器具太多。
# -- Iteration 3 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'search_web'，参数：{'query': '埃塞俄比亚耶加雪菲 咖啡 小红书 评价 风味特点'}
# [Tool Call] 模拟搜索网页：埃塞俄比亚耶加雪菲 咖啡 小红书 评价 风味特点
# Observation: 工具返回结果：未找到关于 '埃塞俄比亚耶加雪菲 咖啡 小红书 评价 风味特点' 的特定信息，但市场反馈通常关注产品成分、功效和用户体验。
# -- Iteration 4 --
# Agent: 决定调用工具...
# Agent Action: 调用工具 'generate_emoji'，参数：{'context': '精致生活 家庭手冲咖啡 简单操作 专业风味 花香柑橘'}
# [Tool Call] 模拟生成表情符号，上下文：精致生活 家庭手冲咖啡 简单操作 专业风味 花香柑橘
# Observation: 工具返回结果：['☕', '💫', '✨', '🌱', '💖']
# -- Iteration 5 --
# [模型生成结果] **Observation**: 获得了5个表情符号：☕（咖啡）、💫（闪耀）、✨（星星）、🌱（新生/自然）、💖（爱心）。这些很适合表达精致生活和咖啡的美好体验。
#
# 现在我有足够的信息来创作文案了：
#
# 1. **标题**：需要吸引眼球，结合"小白也能冲出专业级咖啡"的流行趋势，突出简单和专业
# 2. **正文**：需要包含产品卖点（全套装备、简单操作、精品豆子）、使用体验、适合人群
# 3. **标签**：需要至少5个相关标签，涵盖#手冲咖啡 #家庭咖啡 #精致生活 #咖啡入门等
# 4. **表情符号**：使用刚才生成的5个表情符号
#
# 让我构思一下文案结构：
# - 开头：吸引注意，提出问题或痛点
# - 中间：介绍产品如何解决问题，突出卖点
# - 结尾：呼吁行动，分享使用感受
#
# ```json
# {
#   "title": "小白也能冲出专业级咖啡☕ | 10分钟搞定家庭手冲仪式感",
#   "body": "以前总觉得手冲咖啡好复杂，各种器具眼花缭乱😵\n\n直到入手了这个「家庭手冲咖啡套装」，才发现原来这么简单！✨\n\n🌟 全套装备一次配齐：\n✅ V60滤杯+分享壶\n✅ 精准电子秤+温度计\n✅ 200g埃塞俄比亚耶加雪菲精品豆\n✅ 专用滤纸\n\n💫 操作超简单：\n1️⃣ 磨豆（中细度）\n2️⃣ 92℃热水闷蒸30秒\n3️⃣ 分段注水2-3次\n4️⃣ 2分30秒完成萃取\n\n🌱 风味体验：\n第一口就被惊艳到了！清新的花香扑鼻而来，接着是明亮的柑橘酸质，尾韵带着蜂蜜般的甜感～完全不像新手冲出来的咖啡！\n\n💖 适合人群：\n• 咖啡小白想入门手冲\n• 追求生活仪式感的精致女孩\n• 想在家享受咖啡馆品质的上班族\n\n现在每天早上10分钟，就能给自己一杯专业级的手冲咖啡，幸福感爆棚！💫\n\n#手冲咖啡入门 #家庭咖啡角 #精致生活仪式感",
#   "hashtags": ["#手冲咖啡", "#家庭咖啡", "#精致生活", "#咖啡入门", "#耶加雪菲", "#咖啡仪式感", "#小白咖啡"],
#   "emojis": ["☕", "💫", "✨", "🌱", "💖"]
# }
# ```
# Agent: 任务完成，成功解析最终JSON文案。
#
# --- 【美食饮品】主题文案 ---
# ## 小白也能冲出专业级咖啡☕ | 10分钟搞定家庭手冲仪式感
#
# 以前总觉得手冲咖啡好复杂，各种器具眼花缭乱😵
#
# 直到入手了这个「家庭手冲咖啡套装」，才发现原来这么简单！✨
#
# 🌟 全套装备一次配齐：
# ✅ V60滤杯+分享壶
# ✅ 精准电子秤+温度计
# ✅ 200g埃塞俄比亚耶加雪菲精品豆
# ✅ 专用滤纸
#
# 💫 操作超简单：
# 1️⃣ 磨豆（中细度）
# 2️⃣ 92℃热水闷蒸30秒
# 3️⃣ 分段注水2-3次
# 4️⃣ 2分30秒完成萃取
#
# 🌱 风味体验：
# 第一口就被惊艳到了！清新的花香扑鼻而来，接着是明亮的柑橘酸质，尾韵带着蜂蜜般的甜感～完全不像新手冲出来的咖啡！
#
# 💖 适合人群：
# • 咖啡小白想入门手冲
# • 追求生活仪式感的精致女孩
# • 想在家享受咖啡馆品质的上班族
#
# 现在每天早上10分钟，就能给自己一杯专业级的手冲咖啡，幸福感爆棚！💫
#
# #手冲咖啡入门 #家庭咖啡角 #精致生活仪式感
#
# #手冲咖啡 #家庭咖啡 #精致生活 #咖啡入门 #耶加雪菲 #咖啡仪式感 #小白咖啡

# %% [markdown]
# ## 6. 评估与优化
#
# 文案生成并非一蹴而就，需要持续的评估和优化。本节讨论一些评估方法和优化策略。
#
# #### 评估文案质量：
# *   **客观量化评估 (数据)：**
#     *   **点赞/收藏/评论/分享：** 基础互动
#     *   **曝光/阅读/点击/涨粉：：** 流量与曝光
#     *   **停留时长/截图率：** 用户行为。
#     *   **商品页浏览/加购/ROI/成交转化：** 商业价值
#     *   **爆文率/同类横向对比：** 竞争对比
# *   **主观内部评估 (人工)：**
#     *   **相关性：** 是否符合产品特点和主题。
#     *   **吸引力：** 标题是否抓人，内容是否流畅。
#     *   **合规性：** 是否有敏感词、违规宣传。
#     *   **风格匹配：** 是否符合小红书调性和指定语气。
#     *   **用户画像：** 目标人群年龄、地域、兴趣标签。
#
#
#
# #### 优化迭代方法：
# *   **Prompt 调整：** 根据评估结果，精修 System Prompt、User Prompt，增加或修改 Few-shot 示例。
# *   **工具扩充：** 引入新的工具（如敏感词检测工具、竞品分析工具）。
# *   **RAG (检索增强生成)：** 结合更精准的内部知识库，减少幻觉。

# %% [markdown]
# ## 7. 总结与展望
#
# 通过本次实战，我们成功构建了一个基于 DeepSeek Agent 的小红书爆款文案生成助手。我们学习了如何拆解需求、设计 Prompt、定义工具，并实现 Agent 的核心工作流。
#
# Agent 在内容营销领域的潜力巨大，未来可以进一步拓展到：
#
# *   **超个性化内容：** 根据用户数据，生成一对一的定制文案。
# *   **多模态内容创作：** 结合图片、视频生成，实现图文音视频一体化。
# *   **智能营销决策：** Agent 不仅生成内容，还能分析效果并给出投放建议。
# *   **跨平台适配：** 快速生成适应不同社交媒体平台风格的文案。
#
# 同时，我们也需关注挑战，如确保内容真实性、处理高度主观情感、与现有工作流的无缝集成等。Agent 技术仍在快速发展，期待未来能带来更多惊喜！
